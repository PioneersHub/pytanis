# %%
import os
import sys
import math
import logging
import structlog
from pathlib import Path

import tomli
import numpy as np

# %load_ext autoreload
# %autoreload 2

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import seaborn as sns
sns.set_context("poster")
sns.set(rc={"figure.figsize": (16, 9.)})
sns.set_style("whitegrid")

import pandas as pd
pd.set_option("display.max_rows", 120)
pd.set_option("display.max_columns", 120)

# %%
# Set the logging level
logging.basicConfig(level=logging.WARNING, stream=sys.stdout)

# %%
import pytanis
from pytanis import GSheetsClient, PretalxClient, HelpDeskClient
from pytanis.review import Col
from pytanis.mailgun import Mail, Recipient, MailClient

# %%
# Be aware that this notebook might only run with the following version
pytanis.__version__
# Out:
# '0.7.1.post1.dev5+g54f57c2.d20240618'

# %%
# Import event-specific settings to don't have them here in the notebook
with open('config.toml', 'rb') as fh:
    cfg = tomli.load(fh)

# %% [markdown]
# # Get all the Reviewers

# %%
gsheet_client = GSheetsClient()
gsheet_df = gsheet_client.gsheet_as_df(cfg['reviewer_spread_id'], cfg['reviewer_work_name'])
# rename columns to stick to our convention
col_map = {
 "Topics you want to review": Col.track_prefs,
 "Email address": Col.email,
 "Name": Col.speaker_name,
 "Affiliation": Col.affiliation,
 "Who do you know from the Committee?": Col.committee_contact,
 "Availability during the Review Period": Col.availability,
 "Additional comments regarding your availability during the review period.": Col.availability_comment,
 "Activated in Pretalx": Col.pretalx_activated,
 "Do you want your name to be listed as a reviewer on the conference website?": Col.public,
 "Wants all proposals": Col.all_proposals,
 "Any additional comments for the Program Committee": Col.comment,
 "Committee Member": Col.committee_member
}
gsheet_df.rename(columns=col_map, inplace=True)

# %%
# add column to address people nicely
gsheet_df[Col.address_as] = gsheet_df[Col.speaker_name].apply(lambda x: x.split()[0].title())

# %%
reviewers_all_df = gsheet_df[[Col.speaker_name, Col.email, Col.address_as]]
reviewers_all = reviewers_all_df.apply(lambda x: Recipient(name=x[Col.speaker_name], email=x[Col.email], address_as=x[Col.address_as]), axis=1).to_list()

# %%
# determine reviewers having not even activated the Pretalx Acccount 
reviewers_not_activated_df = gsheet_df.loc[gsheet_df[Col.pretalx_activated].isna(), [Col.speaker_name, Col.email, Col.address_as]]
reviewers_not_activated = reviewers_not_activated_df.apply(lambda x: Recipient(name=x[Col.speaker_name], email=x[Col.email], address_as=x[Col.address_as]), axis=1).to_list()

# TODO: add Committee Member as column to the Reviewers spreadsheet in the Google Drive 
# NOTE: in the last years we have as well excluded  Committee members, which I have not done here as I don't have the information in the Spreadsheet (and I believe sending emails to the committee members is not a problem anyways)
# & gsheet_df[Col.committee_member].isna()

# %%
# TODO: add Pretalx Email as column to the spreadsheet in the Google Drive 
# for activated reviewers we take the e-mail address of their pretalx account
reviewers_activated_df = gsheet_df.loc[gsheet_df[Col.pretalx_activated].notnull()]  # , [Col.speaker_name, 'Pretalx Mail', Col.address_as]
reviewers_activated = reviewers_activated_df.apply(lambda x: Recipient(name=x[Col.speaker_name], email=x['Pretalx Mail'], address_as=x[Col.address_as]), axis=1).to_list()

# %%
pretalx_client = PretalxClient(blocking=True)
revs_count, revs = pretalx_client.reviews(cfg['event_name'])
revs = list(revs)
# Out:
#   0%|          | 0/1554 [00:00<?, ?it/s]

# %%
revs_df_raw = pd.DataFrame([
    {'created': r.created, 'updated': r.updated, Col.pretalx_user: r.user, 'score': r.score, 'review': r.submission}
    for r in revs
])
revs_user_df = revs_df_raw.groupby([Col.pretalx_user]).agg(lambda x: x.tolist()).reset_index()

# %%
reviewers_revs_df = pd.merge(left=reviewers_activated_df, right=revs_user_df, left_on='Pretalx Name', right_on='Pretalx user', how='left')

# %%
reviewers_revs_df = reviewers_revs_df.assign(n_reviews=lambda df: df['review'].apply(lambda x: len(x) if isinstance(x, list) else 0))

# %%
working_reviewers_df = reviewers_revs_df.loc[reviewers_revs_df['n_reviews'] > 0]
non_workign_reviewers_df = reviewers_revs_df.loc[reviewers_revs_df['n_reviews'] == 0]
working_reviewers = working_reviewers_df.apply(lambda x: Recipient(name=x[Col.speaker_name], email=x['Pretalx Mail'], address_as=x[Col.address_as]), axis=1).to_list()
non_working_reviewers = non_workign_reviewers_df.apply(lambda x: Recipient(name=x[Col.speaker_name], email=x['Pretalx Mail'], address_as=x[Col.address_as]), axis=1).to_list()

# %% [markdown]
# # Initial Mail to Reviewers for Onboarding

# %%
mail_body = """
Hi {recipient.address_as}!

I hope this message finds you well. As the Chair of the Programme Committee for PyConDE & PyData,
it's my pleasure to welcome you to our team. Your contribution is vital to the success of our upcoming event.

In the last weeks, you should have received an invitation from noreply@pretalx.com to join Pretalx, our platform for
managing conference submissions. Please follow the link in the email to activate your account and
ensure you keep your login credentials safe.

We will be sending out more detailed information and guidelines in the next few days.
In the meantime, if you encounter any issues signing up or have any questions,
feel free to reach out to us at program25@pycon.de.

Until then, I wish you a great start into the week and am looking forward to working with you!

Warm regards,

Florian Wilhelm
Program Committee Chair
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="Welcome to PyConDE & PyData 2025 Review Team - Important Account Activation Information",
    body=mail_body,
    recipients=reviewers_not_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors

# %% [markdown]
# # Mail to Reviewers that haven't activated their account in Pretalx

# %%
mail_body = """
Hi {recipient.address_as} and welcome to the PyConDE / PyData 2025 review team!

I hope this message finds you well. As the Chair of the Programme Committee for PyConDE & PyData,
it's my pleasure to welcome you to our team. Your contribution is vital to the success of our upcoming event.

In the last few days, you should have received an invitation from noreply@pretalx.com to join Pretalx, our platform for
managing conference submissions. Have you checked your SPAM folder yet as it seems you haven't activated your
Pretalx Account for reviewing. Please follow the link in the Pretalx email to activate your account and ensure you keep
your login credentials safe. PLEASE DO THIS NOW :-)

We will be sending out more detailed information and guidelines in the new year.
In the meantime, if you encounter any issues signing up, can't find the Pretalx email or have any questions,
feel free to reach out to us at program25@pycon.de.

All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="Important! Please activate your Pretalx Account for PyConDE & PyData 2025",
    body=mail_body,
    recipients=reviewers_not_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors

# %% [markdown]
# ## Mail regarding the Review Onboarding

# %%
mail_body = """
Hi {recipient.address_as},

the year 2025 has started and we are all excited about 500 submissions in our Call for Proposal this year!
The Programme Committee is doing right now the final preparations to organise the review process.

We have just updated our Reviewer Guidelines (link below) for you to read before the actual review
process will start today, 6th of January and the deadline is Wednesday, 29th of January Midnight.
To meet your fellow reviewers, have a nice chat, talk to the programme committee and ask questions
personally, we also offer two non-mandatory Get Togethers on the 9th & 16th of January (details below).

If you have any questions, need help, don't hesitate contacting us at program25@pycon.de.
We appreciate your help very much and want to make sure that you are having a good time.

Please start reviewing as soon as possible. We hope to see an average of around 40 reviews of every reviewer
to have in total 3 reviews for each proposal. 

Thank you very much, {recipient.address_as}, for your support!

Summary:
* Review period: 6. January 2025 - 29. January 2025, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines: https://pioneershub.github.io/pyconde25-conference/guidelines/reviewers/#reviewer-guidelines-pycon-de-pydata-2025
* [Nonobligatory] PyCon 2025 - Reviewer's Get Together, Meet & Greet and your Questions:
  - Thursday,  9. January 2025 · 6:00 till 7:00PM CET, video call: https://meet.google.com/ymi-rkaf-uxj
  - Thursday, 16. January 2025 · 6:00 till 7:00PM CET, video call: https://meet.google.com/ezr-rrrn-kyg
* Contact program25@pycon.de for support if needed

IMPORTANT: If you haven't signed up on Pretalx yet, please search for a mail from `noreply@pretalx.com`
           in your mailbox, also SPAM folder and confirm it. It's necessary for our assignment of proposals for review.


All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] Start and Information about the Review Process in 2025",
    body=mail_body,
    recipients=reviewers_all
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors

# %% [markdown]
# ## Mail regarding the Review Onboarding 2 only to activated reviewers

# %%
mail_body = """
Hi {recipient.address_as},

we hope you had a great holiday season, after all you were nice and activated your Pretalx account,
so Santa must have been generous with you ;-) One last bit of information about the review process for
this year. More to come in 2025...

We just assigned every reviewer initially 10 proposals so that you have a chance to familiarize yourself with
Pretalx before the Reviewer's Get Together dates (see below) to ask questions. It's *not* mandatory to participate
and the official review phase will start on January 9th in 2025. So this is just a tidbit of what's to come in 2025.

See you next year and thank you very much {recipient.address_as} for your support!

Summary:
* Review period: 9. January 2025 - 31 January, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines (https://docs.google.com/document/d/1zncTc8gm7OUIIWt175YohriJ5ux7yHkLJFBpQvwNyX8/edit?tab=t.0#heading=h.hfsau13gky5q)
* [Nonobligatory] PyCon 2025 - Reviewer's Get Together, Meet & Greet and your Questions:
  - Thursday, xx. January 2025 · 5:00 bis 5:40PM CET, video call: https://meet.google.com/<xxx>
  - Thursday, xx. January 2025 · 5:00 bis 5:40PM CET, video call: https://meet.google.com/<xxx>
* Contact program25@pycon.de for support if needed

All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] One more thing about the Review Process in 2025",
    body=mail_body,
    recipients=reviewers_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors

# %% [markdown]
# # Mail to Reviewers activated in Pretalx

# %% [markdown]
# ## Mail regarding the Review Onboarding

# %%
mail_body = """
Hi {recipient.address_as},

the end of the year 2024 is near and we are all excited about what's to come in 2025.
The Programme Committee is doing right now the final preparations to organise the review process.

We have just updated our Reviewer Guidelines (link below) for you to read before the actual review
process will start on Wednesday, 9th of January and the deadline is Friday, 31st of January Midnight.
To meet your fellow reviewers, have a nice chat, talk to the programme committee and ask questions
personally, we also offer two non-mandatory Get Togethers on the <xx>th & <xx>th of January (details below).

If you have any questions, need help, don't hesitate contacting us at program25@pycon.de.
We appreciate your help very much and want to make sure that you are having a good time.

Thank you very much, {recipient.address_as}, for your support!

Summary:
* Review period: 9. January 2025 - 31 January, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines (https://docs.google.com/document/d/1zncTc8gm7OUIIWt175YohriJ5ux7yHkLJFBpQvwNyX8/edit?tab=t.0#heading=h.hfsau13gky5q)
* [Nonobligatory] PyCon 2025 - Reviewer's Get Together, Meet & Greet and your Questions:
  - Thursday, xx. January 2025 · 5:00 bis 5:40PM CET, video call: https://meet.google.com/<xxx>
  - Thursday, xx. January 2025 · 5:00 bis 5:40PM CET, video call: https://meet.google.com/<xxx>
* Contact program25@pycon.de for support if needed

IMPORTANT: If you haven't signed up on Pretalx yet, please search for a mail from `noreply@pretalx.com`
           in your mailbox, also SPAM folder and confirm it. It's necessary for our assignment of proposals for review.


All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] Information about the Review Process in 2025",
    body=mail_body,
    recipients=reviewers_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors

# %% [markdown]
# ## Mail regarding the start of the Review Phase

# %%
mail_body = """
Hi {recipient.address_as},

we hope you had a great first of three weeks of reviewing and welcome to your well-deserved weekend :-)
Some more details about this year's reviewing process. For our seasoned pro-reviewers: It's about the same as last year.

We have a new record of 500 submissions this year and as of today a total of 49 onboarded reviewers of which 21 already 
started reviewing. Like last year, we aim  at having 3 reviews per proposal to have a fair evaluation of a proposal's quality. 
This again means that we have to distribute 1,500 reviews over 49 reviewers leading to about 31 reviews per reviewer 
assuming that all reviewers become active. From our experience, the average will rather be 42 reviews per active reviewer.
To make sure we really have 3 reviews per proposal in the end, we will initially assign each proposal to 5 reviewers. 
Whenever a proposal has 3 reviews, it will be removed from the list of proposals to review for the remaining reviewers.
If you have and feedback regarding this process, please let us know :-) 

So let's all begin with the review process and make this year's PyConDE & PyData Darmstadt 2025 the biggest success ever.

If you have any questions, need help, don't hesitate contacting us at program25@pycon.de.
Coming Thursday, there will also be a nice but non-mandatory Get Together, Meet & Great hosted for all reviewers. See below for details.
We appreciate your help very much and want to make sure that you are having a good time.

Thank you very much, {recipient.address_as}, for your support!

Summary:
* Review period: 6. January 2025 - 29. January 2025, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines: https://pioneershub.github.io/pyconde25-conference/guidelines/reviewers/#reviewer-guidelines-pycon-de-pydata-2025
* [Nonobligatory] PyCon 2025 - Reviewer's Get Together, Meet & Greet and your Questions:
  - Thursday,  9. January 2025 · 6:00 till 7:00PM CET, video call: https://meet.google.com/ymi-rkaf-uxj
  - Thursday, 16. January 2025 · 6:00 till 7:00PM CET, video call: https://meet.google.com/ezr-rrrn-kyg
* Contact program25@pycon.de for support if needed

IMPORTANT: If you haven't signed up on Pretalx yet, please search for a mail from `noreply@pretalx.com`
           in your mailbox, also SPAM folder and confirm it. It's necessary for our assignment of proposals for review.

All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] 1. Update regarding our reviewing process",
    body=mail_body,
    recipients=reviewers_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors
# Out:
#   0%|          | 0/49 [00:00<?, ?it/s]

# %% [markdown]
# ## Mail after 2 week or reviews

# %%
mail_body = """
Hi {recipient.address_as},

the second of three weeks of the reviews phase is coming to an end and 75% of all reviewers have already started reviewing. 
You are one of them 🚀. Thank you very much for your efforts. We have accomplished together already 82.1% of all necessary reviews. That's great!

Some reviewers have even already accomplished their allocated batch of submissions 😍
This is just awesome! If you are one of them, it's time to relax or in case you want more, just let us know.

So let's keep up the good work and finish the review process by January 29th.

Thank you very much, {recipient.address_as}, for your support!

Summary:
* Review period: 6. January 2025 - 29. January 2025, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines: https://pioneershub.github.io/pyconde25-conference/guidelines/reviewers/#reviewer-guidelines-pycon-de-pydata-2025
* Contact program25@pycon.de for support if needed

All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] Second week of the Review Phase",
    body=mail_body,
    recipients=working_reviewers
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors
# Out:
#   0%|          | 0/39 [00:00<?, ?it/s]

# %%
mail_body = """
Hi {recipient.address_as},

the second of three weeks of the reviews phase is coming to an end and 75% of all reviewers have already started reviewing. 
Sadly you are not one of them 🥲 but surely the deadline was just not close enough. Now it is! 😉

In any case, if life got in your way and you won't be able to accomplish your reviews, it's no problem, just please let us know
so that we can move your submissions to another reviewer.

Thank you very much, {recipient.address_as}, for your support!

Summary:
* Review period: 6. January 2025 - 29. January 2025, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines: https://pioneershub.github.io/pyconde25-conference/guidelines/reviewers/#reviewer-guidelines-pycon-de-pydata-2025
* Contact program25@pycon.de for support if needed

All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] Second week of the Review Phase",
    body=mail_body,
    recipients=non_working_reviewers
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors
# Out:
#   0%|          | 0/13 [00:00<?, ?it/s]

# %% [markdown]
# ## Mail after 2 week or reviews

# %%
mail_body = """
Hi {recipient.address_as},

the second of three weeks of the review phase are over and <xx>% of all reviewers have already started.
We have accomplished together already about two third of all necessary reviews. That's great!

If you haven't started yet, please do so now. We are almost there! ONLY 9 DAYS LEFT.
So let's keep up the good work and finish the review process by the end of January.

Thank you very much, {recipient.address_as}, for your support!

Information summary:
* Please review all assigned proposals but at least <xx> proposals :-)
* Review period: 9. January 2025 - 31 January, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines (https://docs.google.com/document/d/1zncTc8gm7OUIIWt175YohriJ5ux7yHkLJFBpQvwNyX8/edit?tab=t.0#heading=h.hfsau13gky5q)
* Contact program25@pycon.de for support if needed

All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] ONLY 9 DAYS LEFT!",
    body=mail_body,
    recipients=reviewers_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors

# %% [markdown]
# ## Mail after 3 week or reviews

# %%
pretalx_client = PretalxClient()
n_reviews, reviews = pretalx_client.reviews(cfg['event_name'])
reviews = list(reviews)

# %%
scored_reviews_df = pd.DataFrame([{"user": r.user, "score": r.score, "n_reviews": r.submission} for r in reviews if r.score is not None])
scored_reviews_df = scored_reviews_df.groupby("user").count()[["n_reviews"]]
scored_reviews_df['top_perc'] =  (1. - scored_reviews_df.rank(pct=True)["n_reviews"])

# %%
reviewers_activated_df = pd.merge(reviewers_activated_df, scored_reviews_df, right_on='user', left_on='Pretalx Name', how='left')
reviewers_activated_df["n_reviews"].fillna(0., inplace=True)
# Out:
# /var/folders/ts/4k10rtg93lb9rpbs7m08v8480000gn/T/ipykernel_12956/1973983135.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   reviewers_activated_df["n_reviews"].fillna(0., inplace=True)

# %%
def get_feedback(x):
    if x['n_reviews'] == 0.:
        return "So far you haven't reviewed any proposals, it seems. Now it's really time to get started :-)\nPlease let us know if you are not able to review for some reason. In this case, we must assign your proposals to others soon."
    elif x['n_reviews'] < 20.:
        return "You have reviewed only a few proposals so far, less than 20. Please review some more proposals.\nWe are close to the finish line."
    else:
        return f"Thanks that you already supported us so much! We are close to the finish line.\nIf you have time, please review some more proposals."

reviewers_activated_df["feedback"] = reviewers_activated_df.apply(get_feedback, axis=1)

# %%
reviewers_activated = reviewers_activated_df.apply(lambda x: Recipient(name=x[Col.speaker_name], 
                                                                  email=x[Col.email], 
                                                                  address_as=x[Col.address_as], 
                                                                  data={"feedback": x["feedback"]}),  axis=1).to_list()

# %%
mail_body = """
Hi {recipient.address_as},

it's the final countdown, only 5 days left until the end of the review phase
and yet we have more than <xx>% of all necessary reviews missing :-(
{recipient.data.feedback}

Thank you very much, {recipient.address_as}, for your support!

Information summary:
* Please review all assigned proposals but at least 22 proposals :-)
* Review period: 9. January 2025 - 31 January, 00:00 CET
* Pretalx: https://pretalx.com/orga/event/pyconde-pydata-2025/reviews/
* Reviewer Guidelines (https://docs.google.com/document/d/1zncTc8gm7OUIIWt175YohriJ5ux7yHkLJFBpQvwNyX8/edit?tab=t.0#heading=h.hfsau13gky5q)
* Contact program25@pycon.de for support if needed

All the best,
Program Committee
PyCon DE & PyData Daarmstadt 2025
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] ONLY 5 DAYS LEFT FOR YOUR REVIEWS!",
    body=mail_body,
    recipients=reviewers_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors

# %% [markdown]
# ## Mail End of Review!

# %%
reviewers_activated_df
# Out:
#               Timestamp                              Email  \
# 0   26/11/2024 08:54:55          immo.barth@oldendorff.com
# 1   27/11/2024 09:15:42           medaminejebari@gmail.com
# 2   27/11/2024 09:17:41                 anjapilz@gmail.com
# 3   27/11/2024 09:30:51                  fabian@hadiji.com
# 4   28/11/2024 06:52:05             masamori0083@gmail.com
# 5   28/11/2024 16:32:50                Schrammsm@gmail.com
# 6   02/12/2024 10:31:28                  xitstha@gmail.com
# 7   02/12/2024 17:21:03              simonkufeld@gmail.com
# 8   02/12/2024 18:10:15           shahrzadhadian@gmail.com
# 9   02/12/2024 18:10:25           nefta.kanilmaz@gmail.com
# 10  02/12/2024 18:10:54        ricardo.kawase@adevinta.com
# 11  02/12/2024 18:11:42                  rb.proj@gmail.com
# 12  02/12/2024 18:12:09                mail@nils-finke.com
# 13  02/12/2024 18:24:19                    mmohr@inovex.de
# 14  02/12/2024 18:24:57       christopher.schultz@pycon.de
# 15  02/12/2024 18:42:49             daniel.hieber@pycon.de
# 16  02/12/2024 18:57:44         nashiorkornortey@gmail.com
# 17  02/12/2024 19:58:17            ashmi.banerjee@pycon.de
# 18  02/12/2024 20:44:55              dennis.weyland@web.de
# 19  03/12/2024 17:32:01           karen.pedie@adevinta.com
# 20  04/12/2024 08:02:54            pia.s.schmidt@gmail.com
# 22  06/12/2024 14:00:08     francesca.diana@codecentric.de
# 23  08/12/2024 11:58:32          Florian.Wilhelm@gmail.com
# 24  08/12/2024 12:02:03     lisa.chalaguine@googlemail.com
# 25  08/12/2024 17:49:55          jurik.eineemail@gmail.com
# 26  09/12/2024 00:04:05       maryam.poorranjbar@gmail.com
# 27  10/12/2024 08:39:30                      luixx@gmx.net
# 28  11/12/2024 20:20:08   benedict.kuchenmeister@gmail.com
# 29  15/12/2024 10:02:45                 l.marxen@posteo.de
# 30  16/12/2024 14:34:35          moritz.wegener1@gmail.com
# 31  16/12/2024 14:39:27                 python@juliobs.com
# 32  16/12/2024 14:55:38          cenk.bircanoglu@gmail.com
# 33  16/12/2024 14:58:31             alex.tello.g@gmail.com
# 34  16/12/2024 16:36:25           davidweisspost@gmail.com
# 35  16/12/2024 22:50:42          jannik_sundermeier@web.de
# 36  16/12/2024 23:34:34             adrian.castro@tacto.ai
# 37  17/12/2024 08:04:56              max.koeppel@inovex.de
# 38  17/12/2024 09:28:26     sven.giesselbach@t-systems.com
# 39  17/12/2024 10:47:26    cedric.wilting+pydata@gmail.com
# 40  17/12/2024 13:27:50             steven.tjong@inovex.de
# 41  17/12/2024 19:58:46                karavdina@gmail.com
# 42  18/12/2024 19:51:52                 bossenti@posteo.de
# 43  19/12/2024 12:24:42                kdomhardt@gmail.com
# 44  19/12/2024 18:25:44          matthias@albertinvent.com
# 45  24/12/2024 12:12:26  julia.monika.kannenberg@gmail.com
# 46  28/12/2024 22:56:46          kristian.rother@posteo.de
# 47  02/01/2025 22:05:50     alexandra.woerner@scieneers.de
# 48  05/01/2025 07:41:52        khusaal.giri@blueyonder.com
# 49  07/01/2025 20:59:46         nastya.samokhina@gmail.com
# 50  08/01/2025 11:39:46          jeroenoverschie@gmail.com
# 51  15/01/2025 15:16:50                  pycon@a-kunkel.de
# 52  15/01/2025 22:06:20           franz.woellert@gmail.com
#
#                      Speaker name                             Affiliation  \
# 0                      Immo Barth                Oldendorff Carriers GmbH
# 1            Mohamed Amine Jebari                                TD Reply
# 2                       Anja Pilz                                 DAMEDIC
# 3                   Fabian Hadiji                                   Lotum
# 4                 Masahiro Morino                               moegi inc
# 5               Sebastian Schramm                                Crisis24
# 6                 Manjil Shrestha                Platform X GmbH & Co. KG
# 7                    Simon Kufeld                          mobile.de GmbH
# 8                   Sherri Hadian                                    SAP
# 9             Umut Nefta Kanilmaz                  University of Salzburg
# 10                 Ricardo Kawase                               mobile.de
# 11                   Reimar Bauer           Forschungszentrum Jülich GmbH
# 12                      Nils Mohr         Egon Oldendorff Management GmbH
# 13                    Marisa Mohr                             inovex GmbH
# 14            Christopher Schultz    University of Maryland Global Campus
# 15                  Daniel Hieber  Neu-Ulm University of Applied Sciences
# 16           Naa Ashiorkor Nortey                      Tampere University
# 17                 Ashmi Banerjee          Technical University of Munich
# 18                 Dennis Weyland                             Blue Yonder
# 19                    Karen Pedie                                Adevinta
# 20                    Pia Schmidt                             inovex GmbH
# 22                Francesca Diana                          codecentric AG
# 23                Florian Wilhelm                             inovex GmbH
# 24                Lisa Chalaguine                           Digital Nomad
# 25                   Jurik Summer                        Deutsche Telekom
# 26             Maryam Pourranjbar                                     MHP
# 27                  Karsten Wilke                       T-Systems onsite
# 28         Benedict Kuchenmeister                            Damedic GmbH
# 29                     Lea Marxen                              ARD Online
# 30                 Moritz Wegener                             X-INTEGRATE
# 31            Julio Batista Silva                       Hoppe Marine GmbH
# 32                Cenk Bircanoglu                                Adevinta
# 33                   Alexis Tello                                TD Reply
# 34                     David Weiß                        Deutsche Telekom
# 35                Jannik Castenow                               ITSC GmbH
# 36  Adrian David Castro Tenemaya                               Tanto GmbH
# 37                    Max Koeppel                             inovex GmbH
# 38               Sven Giesselbach                               T-Systems
# 39                 Cedric Wilting                 MHP - A Porsche Company
# 40        Steven Arigunawan Tjong                             inovex GmbH
# 41            Anastasia Karavdina                              Vattenfall
# 42                Tim Bossenmaier                        Cloudflight GmbH
# 43                     Kai Storms                            TU Darmstadt
# 44               Matthias Hofmann                           albert invent
# 45               Julia Kannenberg                                   DeepL
# 46                Kristian Rother                                Academis
# 47               Alexandra Wörner                               scieneers
# 48                   Khusaal Giri                             Blue Yonder
# 49            Anastasia Samokhina                             Planet Labs
# 50               Jeroen Overschie                                   Xebia
# 51                    Anja Kunkel                             Mister Spex
# 52                 Franz Wöllert              Heidelberger Druckmaschinen
#
#                                     Committee Contact  \
# 0                                          Nils Finke
# 1                                           Anja Pilz
# 2                                              myself
# 3                                           Anja Pilz
# 4                      I'm a program committee member
# 5                                           Anja Pilz
# 6                                           Anja Pilz
# 7                                      Ricardo Kawase
# 8                                              Sherri
# 9                                              Myself
# 10                                           Everyone
# 11                                  Mike, Alex, Nefta
# 12                    Marisa, Simon, Florian, ... :-)
# 13                                            Florian
# 14                                  self (everyone ;)
# 15                                           Everyone
# 16  I am a member of the program committee for PyC...
# 17                                   I am a PC member
# 18                 Nefta Kanilmaz, Sebastian Neubauer
# 19                                     Ricardo Kawase
# 20                                    Florian Wilhelm
# 22                                     Ricardo Kawase
# 23                                    Florian Wilhelm
# 24                                    Lisa Chalaguine
# 25                                       Jurik Sommer
# 26                                    Florian Wilhelm
# 27                                       Jurik Sommer
# 28                                          Anja Pilz
# 29                                    Florian Wilhelm
# 30                     Sherri Hadian, Florian Wilhelm
# 31                  Many. I was a reviewer last year.
# 32                                      Sherri Hadian
# 33                                          Anja Pilz
# 34                                       Jurik Sommer
# 35                                      Sherri Hadian
# 36  I don't *know* anybody, but got sent this form...
# 37                                    Florian Wilhelm
# 38                                          Anja Pilz
# 39            Florian Wilhelm, via Maryam Pourranjbar
# 40  I am quite well informed from my colleagues in...
# 41                               Sebastian Neubauer
# 42                                    Florian Wilhelm
# 43                                                NaN
# 44                                             sherri
# 45                                          Anja Pilz
# 46                               Alex, Paula Gonzalez
# 47                                    Florian Wilhelm
# 48                                    Florian Wilhelm
# 49                                            Florian
# 50                                    Florian Wilhelm
# 51                                    Florian Wilhelm
# 52                                    Florian Wilhelm
#
#                                        Availability  \
# 0   Yes, I am broadly available during this period.
# 1   Yes, I am broadly available during this period.
# 2   Yes, I am broadly available during this period.
# 3   Yes, I am broadly available during this period.
# 4   Yes, I am broadly available during this period.
# 5   Yes, I am broadly available during this period.
# 6   Yes, I am broadly available during this period.
# 7   Yes, I am broadly available during this period.
# 8   Yes, I am broadly available during this period.
# 9   Yes, I am broadly available during this period.
# 10  Yes, I am broadly available during this period.
# 11  Yes, I am broadly available during this period.
# 12  Yes, I am broadly available during this period.
# 13  Yes, I am broadly available during this period.
# 14  Yes, I am broadly available during this period.
# 15  Yes, I am broadly available during this period.
# 16  Yes, I am broadly available during this period.
# 17  Yes, I am broadly available during this period.
# 18  Yes, I am broadly available during this period.
# 19  Yes, I am broadly available during this period.
# 20  Yes, I am broadly available during this period.
# 22  Yes, I am broadly available during this period.
# 23  Yes, I am broadly available during this period.
# 24  Yes, I am broadly available during this period.
# 25  Yes, I am broadly available during this period.
# 26  Yes, I am broadly available during this period.
# 27  Yes, I am broadly available during this period.
# 28  Yes, I am broadly available during this period.
# 29  Yes, I am broadly available during this period.
# 30  Yes, I am broadly available during this period.
# 31  Yes, I am broadly available during this period.
# 32  Yes, I am broadly available during this period.
# 33  Yes, I am broadly available during this period.
# 34  Yes, I am broadly available during this period.
# 35  Yes, I am broadly available during this period.
# 36  Yes, I am broadly available during this period.
# 37  Yes, I am broadly available during this period.
# 38  Yes, I am broadly available during this period.
# 39  Yes, I am broadly available during this period.
# 40  Yes, I am broadly available during this period.
# 41  Yes, I am broadly available during this period.
# 42  Yes, I am broadly available during this period.
# 43  Yes, I am broadly available during this period.
# 44  Yes, I am broadly available during this period.
# 45  Yes, I am broadly available during this period.
# 46  Yes, I am broadly available during this period.
# 47  Yes, I am broadly available during this period.
# 48  Yes, I am broadly available during this period.
# 49  Yes, I am broadly available during this period.
# 50  Yes, I am broadly available during this period.
# 51  Yes, I am broadly available during this period.
# 52  Yes, I am broadly available during this period.
#
#                                  Availability Comment  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                  Thank you for your consideration!
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38  I am available in the beginning of this period...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                  -
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
#
#                                     Track Preferences Public  \
# 0   PyCon: MLOps & DevOps, PyData: Data Handling &...    Yes
# 1   PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 2   PyCon: Testing, PyData: Machine Learning & Dee...    Yes
# 3   PyCon: Testing, PyData: Data Handling & Engine...    Yes
# 4   PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 5   PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 6   PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 7   PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 8   PyCon: Python Language & Ecosystem, PyData: Ma...    Yes
# 9   PyData: Data Handling & Engineering, PyData: M...    Yes
# 10  PyCon: Programming & Software Engineering, PyC...    Yes
# 11  PyCon: Programming & Software Engineering, PyC...    Yes
# 12  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 13  PyData: Machine Learning & Deep Learning & Sta...    Yes
# 14  PyCon: Python Language & Ecosystem, PyCon: Dja...    Yes
# 15  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 16  PyData: Machine Learning & Deep Learning & Sta...    Yes
# 17  PyData: Machine Learning & Deep Learning & Sta...    Yes
# 18  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 19  PyData: Machine Learning & Deep Learning & Sta...    Yes
# 20  PyCon: MLOps & DevOps, PyCon: Programming & So...     No
# 22  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 23  PyCon: Programming & Software Engineering, PyC...    Yes
# 24  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 25  PyCon: MLOps & DevOps, PyCon: Python Language ...    Yes
# 26  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 27  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 28  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 29  PyData: Data Handling & Engineering, PyData: M...    Yes
# 30  PyData: Data Handling & Engineering, PyData: M...    Yes
# 31  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 32  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 33  PyCon: MLOps & DevOps, PyData: Machine Learnin...    Yes
# 34  PyCon: MLOps & DevOps, PyData: Data Handling &...    Yes
# 35  PyCon: Programming & Software Engineering, PyC...    Yes
# 36  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 37  PyCon: MLOps & DevOps, PyData: Data Handling &...    Yes
# 38  PyCon: MLOps & DevOps, PyData: Data Handling &...    Yes
# 39  PyCon: MLOps & DevOps, PyCon: Python Language ...    Yes
# 40  PyCon: MLOps & DevOps, PyCon: Python Language ...    Yes
# 41  PyCon: MLOps & DevOps, PyData: Machine Learnin...    Yes
# 42  PyCon: Programming & Software Engineering, PyC...    Yes
# 43  PyData: Data Handling & Engineering, PyData: M...    Yes
# 44  PyCon: Python Language & Ecosystem, PyCon: Tes...    Yes
# 45  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 46  PyCon: Programming & Software Engineering, PyC...    Yes
# 47  PyCon: MLOps & DevOps, PyCon: Testing, PyData:...    Yes
# 48  PyData: Data Handling & Engineering, PyData: M...     No
# 49  PyCon: Programming & Software Engineering, PyC...    Yes
# 50  PyCon: MLOps & DevOps, PyCon: Programming & So...    Yes
# 51  PyCon: Programming & Software Engineering, PyC...    Yes
# 52  PyCon: Programming & Software Engineering, PyC...    Yes
#
#                                               Comment Pretalx activated  \
# 0                                                 NaN                 x
# 1                                                 NaN                 x
# 2                                                 NaN                 x
# 3                                                 NaN                 x
# 4                                                 NaN                 x
# 5                                                 NaN                 x
# 6                                                 NaN                 x
# 7                                                 NaN                 x
# 8                                                 NaN                 x
# 9                                                 NaN                 x
# 10                                                NaN                 x
# 11                                                NaN                 x
# 12                                                NaN                 x
# 13                                                NaN                 x
# 14                                                NaN                 x
# 15                                                NaN                 x
# 16                                                NaN                 x
# 17                                                NaN                 x
# 18                                                NaN                 x
# 19                                                NaN                 x
# 20                                                NaN                 x
# 22                                                NaN                 x
# 23                                                NaN                 x
# 24                                                NaN                 x
# 25                                                NaN                 x
# 26                                                NaN                 x
# 27                                                NaN                 x
# 28                                                NaN                 x
# 29                                                NaN                 x
# 30                                                NaN                 x
# 31                                                NaN                 x
# 32                                                NaN                 x
# 33                                Keep being awesome!                 x
# 34                                                NaN                 x
# 35                                                NaN                 x
# 36        If I can help with anything, let me know :)                 x
# 37                                                NaN                 x
# 38                                                NaN                 x
# 39                                                NaN                 x
# 40                                                NaN                 x
# 41                                                NaN                 x
# 42  Would enjoy to serve as a volunteer again afte...                 x
# 43                                                NaN                 x
# 44                                                NaN                 x
# 45                                                NaN                 x
# 46                                                NaN                 x
# 47                                                NaN                 x
# 48                                                NaN                 x
# 49                                                NaN                 x
# 50                                         Good work!                 x
# 51                                                NaN                 x
# 52                                                NaN                 x
#
#    All Proposals                       Pretalx Mail  \
# 0            NaN               immotraupe@gmail.com
# 1            NaN           medaminejebari@gmail.com
# 2            NaN            anjapilz@googlemail.com
# 3            NaN                  fabian@hadiji.com
# 4            NaN             masamori0083@gmail.com
# 5            NaN                Schrammsm@gmail.com
# 6            NaN                  xitstha@gmail.com
# 7              x          simon.kufeld@adevinta.com
# 8              x           shahrzadhadian@gmail.com
# 9            NaN           nefta.kanilmaz@gmail.com
# 10             x        ricardo.kawase@adevinta.com
# 11             x                  rb.proj@gmail.com
# 12           NaN                  mail@nils-mohr.de
# 13           NaN                    mmohr@inovex.de
# 14           NaN      christopher.schultz@pycon.com
# 15             x             daniel.hieber@pycon.de
# 16           NaN         nashiorkornortey@gmail.com
# 17             x             mail@ashmibanerjee.com
# 18             x              dennis.weyland@web.de
# 19           NaN           karen.pedie@adevinta.com
# 20           NaN            pia.s.schmidt@gmail.com
# 22           NaN     francesca.diana@codecentric.de
# 23             x          Florian.Wilhelm@gmail.com
# 24             x     lisa.chalaguine@googlemail.com
# 25           NaN          jurik.eineemail@gmail.com
# 26           NaN       maryam.poorranjbar@gmail.com
# 27           NaN                      luixx@gmx.net
# 28           NaN  benedict.kuchenmeister@damedic.ai
# 29           NaN                 l.marxen@posteo.de
# 30           NaN          moritz.wegener1@gmail.com
# 31           NaN                pretalx@juliobs.com
# 32           NaN          cenk.bircanoglu@gmail.com
# 33           NaN             alex.tello.g@gmail.com
# 34           NaN           davidweisspost@gmail.com
# 35             x                   mail@janniksu.de
# 36           NaN             adrian.castro@tacto.ai
# 37           NaN              max.koeppel@inovex.de
# 38           NaN     sven.giesselbach@t-systems.com
# 39           NaN   cedric.wilting+pretalx@gmail.com
# 40           NaN                   stjong@inovex.de
# 41           NaN                karavdina@gmail.com
# 42           NaN                 bossenti@posteo.de
# 43           NaN                kdomhardt@gmail.com
# 44           NaN          matthias@albertinvent.com
# 45           NaN  julia.monika.kannenberg@gmail.com
# 46           NaN                krother@academis.eu
# 47           NaN     alexandra.woerner@scieneers.de
# 48           NaN        khusaal.giri@blueyonder.com
# 49           NaN         nastya.samokhina@gmail.com
# 50           NaN         jeroen.overschie@xebia.com
# 51           NaN         pycon-pretalkx@a-kunkel.de
# 52           NaN           franz.woellert@gmail.com
#
#                          Pretalx Name   Address as
# 0                          Immo Barth         Immo
# 1                Mohamed Amine Jebari      Mohamed
# 2                           Anja Pilz         Anja
# 3                       Fabian Hadiji       Fabian
# 4                        masamori0083     Masahiro
# 5                   Sebastian Schramm    Sebastian
# 6                     Manjil Shrestha       Manjil
# 7                        Simon Kufeld        Simon
# 8                       Sherri Hadian       Sherri
# 9                      Nefta Kanilmaz         Umut
# 10                     Ricardo Kawase      Ricardo
# 11                       Reimar Bauer       Reimar
# 12                          Nils Mohr         Nils
# 13                        Marisa Mohr       Marisa
# 14                Christopher Schultz  Christopher
# 15                      Daniel Hieber       Daniel
# 16               Naa Ashiorkor Nortey          Naa
# 17                     Ashmi Banerjee        Ashmi
# 18                     Dennis Weyland       Dennis
# 19                        Karen Pedie        Karen
# 20                        Pia Schmidt          Pia
# 22                    Francesca Diana    Francesca
# 23                    Florian Wilhelm      Florian
# 24      Dr. Lisa Andreevna Chalaguine         Lisa
# 25                       Jurik Sommer        Jurik
# 26                             Maryam       Maryam
# 27                      Karsten Wilke      Karsten
# 28  benedict.kuchenmeister@damedic.ai     Benedict
# 29                         Lea Marxen          Lea
# 30                     Moritz Wegener       Moritz
# 31                Julio Batista Silva        Julio
# 32                    Cenk Bircanoglu         Cenk
# 33                Alexis Tello Guerra       Alexis
# 34                         David Weiß        David
# 35                    Jannik Castenow       Jannik
# 36                      Adrian Castro       Adrian
# 37                        Max Koeppel          Max
# 38                   Sven Giesselbach         Sven
# 39                             Cedric       Cedric
# 40                       Steven Tjong       Steven
# 41                Anastasia Karavdina    Anastasia
# 42                    Tim Bossenmaier          Tim
# 43                         Kai Storms          Kai
# 44                   Matthias Hofmann     Matthias
# 45                   Julia Kannenberg        Julia
# 46                Dr. Kristian Rother     Kristian
# 47                   Alexandra Wörner    Alexandra
# 48                       Khusaal Giri      Khusaal
# 49                        Anastasia S    Anastasia
# 50                   Jeroen Overschie       Jeroen
# 51                        Anja Kunkel         Anja
# 52                      Franz Wöllert        Franz

# %%
good = """
For all reviewers with more than 20 reviews, we have prepared two tokens of appreciation for you :) 
Swag and IRL experience! Curious? Please check this form and submit your details. 
https://forms.gle/DTWj4vSnLA6Mreft7
"""

def get_feedback(x):
    if x['n_reviews'] >= 20.:
        return good
    else:
        return 'Every little contribution counts, so maybe see you next year again as reviewer :-)'

reviewers_activated_df["feedback"] = reviewers_activated_df.apply(get_feedback, axis=1)

# %%
reviewers_activated = reviewers_activated_df.apply(lambda x: Recipient(name=x[Col.speaker_name], 
                                                                  email=x[Col.email], 
                                                                  address_as=x[Col.address_as], 
                                                                  data={"feedback": x["feedback"]}),  axis=1).to_list()

# %%
#reviewers_activated = [rev for rev in reviewers_activated if rev.name == "Florian Wilhelm"]

# %%
mail_body = """
Hi {recipient.address_as},

A big thank you for your time and effort in reviewing for PyCon DE & PyData 2025! 
Your work is what makes this community thrive, and we’re truly grateful for your support 
and deeply appreciate the time, effort and love you have put into it. 🤗

{recipient.data.feedback}

Together, 49 active of 52 registered reviewers wrote about 1500 reviews for roughly 500 proposals.
We also finished the review phase two days early! That's amazing!

All the best,
Program Committee
PyCon DE & PyData Darmstadt 2025 (program25@pycon.de)
"""

# %%
mail = Mail(
    subject="[PyConDE/PyData 2025] The Review Phase is Over!",
    body=mail_body,
    recipients=reviewers_activated
)

# %%
mail_client = MailClient()
responses, errors = mail_client.send(mail)
assert not errors
# Out:
#   0%|          | 0/52 [00:00<?, ?it/s]
